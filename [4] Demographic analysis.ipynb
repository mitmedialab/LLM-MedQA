# %% [markdown]
# # Demographic Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import re
import numpy as np

# %%
#Load Dataset - SURVEYS
Survey_1 = pd.read_csv("/work/data/2) cleaned_data/Cleaned - Survey 1.csv")
Survey_2 = pd.read_csv("/work/data/2) cleaned_data/Cleaned - Survey 2.csv")
Survey_3 = pd.read_csv("/work/data/2) cleaned_data/Cleaned - Survey 3.csv")

# %%
Surveys = [Survey_1, Survey_2, Survey_3]
Survey_names = ["Survey 1", "Survey 2", "Survey 3"]

def Demo_analysis(demo, demo_categories):
    df_perc = pd.DataFrame()
    df_perc.insert(0, "Survey", 0)

    for c in range(len(demo_categories)):
        category = demo_categories[c]
        df_perc.insert(c+1, str(category), 0)

    Survey_demographics = {}

    for k in range(len(Surveys)):

        survey_list = Surveys[k].loc[:, demo]
    
        demo_list = list(np.zeros(len(demo_categories)))

        for sample in survey_list:
            for i in range(len(demo_categories)):
                if sample == demo_categories[i]:
                    demo_list[i] = demo_list[i] + 1
        
        Survey_demographics[Survey_names[k]] = (demo_list, sum(demo_list), len(survey_list))

        
    return(demo, Survey_demographics)

# %%
Age_categories = ['18-24', '25-34', '35-49', '50-64', '65+']
Demo_analysis('age', Age_categories)
# Out:
# ('age',
#  {'Survey 1': ([16.0, 41.0, 26.0, 12.0, 1.0], 96.0, 96),
#   'Survey 2': ([16.0, 31.0, 37.0, 9.0, 5.0], 98.0, 98),
#   'Survey 3': ([21.0, 38.0, 24.0, 15.0, 2.0], 100.0, 100)})

# %%
Ethn_categories = ['White / Caucasian', 'Hispanic / Latino', 'Black / African American', 'Native American / American Indian', 'Asian / Pacific Islander', 'Other']
Demo_analysis('ethnicity', Ethn_categories)
# Out:
# ('ethnicity',
#  {'Survey 1': ([63.0, 8.0, 9.0, 0.0, 14.0, 2.0], 96.0, 96),
#   'Survey 2': ([76.0, 5.0, 9.0, 0.0, 7.0, 1.0], 98.0, 98),
#   'Survey 3': ([73.0, 13.0, 7.0, 1.0, 6.0, 0.0], 100.0, 100)})

# %%
Edu_categories = ['Less than high school degree', 'High school degree or equivalent (e.g. GED)', 'Some college but not degree', 'Associate degree', 'Bachelor degree', 'Ph.D. or higher','Trade school', 'Prefer not to say', 'Other']
Demo_analysis('education', Edu_categories)
# Out:
# ('education',
#  {'Survey 1': ([1.0, 12.0, 21.0, 13.0, 39.0, 6.0, 2.0, 0.0, 2.0], 96.0, 96),
#   'Survey 2': ([2.0, 11.0, 25.0, 5.0, 41.0, 9.0, 0.0, 0.0, 5.0], 98.0, 98),
#   'Survey 3': ([2.0, 19.0, 25.0, 8.0, 36.0, 3.0, 0.0, 1.0, 6.0], 100.0, 100)})

# %%
Gender_categories = ['Male', 'Female', 'Non-binary', 'Other', 'Prefer not to response']
Demo_analysis('gender', Gender_categories)
# Out:
# ('gender',
#  {'Survey 1': ([48.0, 45.0, 2.0, 0.0, 1.0], 96.0, 96),
#   'Survey 2': ([43.0, 49.0, 4.0, 0.0, 2.0], 98.0, 98),
#   'Survey 3': ([47.0, 49.0, 4.0, 0.0, 0.0], 100.0, 100)})

# %%
Health_Answers = ['Urine', 'Work', 'Treatment', 'Healthy', 'Loss', 'Virus', 'Addiction', 'Birth', 'Dizzy', 'Amount', 'Growth', 'Different', 'Instruction', 'Anxiety', 'Blocked', 'Evaluation', 'Veins', 'Condom']

for survey in Surveys:
    pie_chart_labels = ["High Literacy", "Low Literacy"]
    pie_chart_scores = [0,0]

    for row in range(len(survey)):
        individ_score = 0
        for i in range(18):
            health_ques = "Health_lit_" + str(i+1)
            health_answer = survey.loc[row, health_ques]
            if health_answer == Health_Answers[i]:
                individ_score = individ_score + 1
        if individ_score > 14:
            pie_chart_scores[0] = pie_chart_scores[0] + 1
        else:
            pie_chart_scores[1] = pie_chart_scores[1] + 1

    fig = plt.figure(figsize =(10, 7))
    plt.pie(pie_chart_scores, labels = pie_chart_labels)
 
    # show plot
    plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=28896330-bd0f-4f0f-a160-af87c463253f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
